# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
from imutils import paths
import pickle
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

# Function to extract common features from an image
def extract_common_features(image):
    # Color Features
    color_features = extract_color_features(image)

    # Texture Features
    texture_features = extract_texture_features(image)

    # Shape Features
    shape_features = extract_shape_features(image)

    # Combine all features
    common_features = np.hstack([color_features, texture_features, shape_features])

    return common_features

# Function to extract color features from an image
def extract_color_features(image):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mean_hue = np.mean(hsv_image[:,:,0])
    mean_saturation = np.mean(hsv_image[:,:,1])
    mean_value = np.mean(hsv_image[:,:,2])
    std_hue = np.std(hsv_image[:,:,0])
    std_saturation = np.std(hsv_image[:,:,1])
    std_value = np.std(hsv_image[:,:,2])
    color_features = np.array([mean_hue, mean_saturation, mean_value, std_hue, std_saturation, std_value])
    return color_features

# Function to extract texture features from an image
def extract_texture_features(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    mean_texture = np.mean(gray_image)
    std_texture = np.std(gray_image)
    texture_features = np.array([mean_texture, std_texture])
    return texture_features

# Function to extract shape features from an image
def extract_shape_features(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    contours, _ = cv2.findContours(gray_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour_area = 0
    contour_perimeter = 0
    contour_count = len(contours)
    for contour in contours:
        contour_area += cv2.contourArea(contour)
        contour_perimeter += cv2.arcLength(contour, True)
    shape_features = np.array([contour_area, contour_perimeter, contour_count])
    return shape_features

# Function to load dataset
def load_dataset(datasetPath):
    print("[INFO] Loading dataset from", datasetPath)
    imagePaths = list(paths.list_images(datasetPath))
    data = []
    # Loop over the image paths
    for imagePath in imagePaths:
        print("[INFO] Processing image", imagePath)
        # Load the image
        image = cv2.imread(imagePath)
        if image is None:
            print("[WARNING] Failed to read image file:", imagePath)
            continue
        # Extract features
        features = extract_common_features(image)
        data.append(features)
    print("[INFO] Dataset loaded successfully. Total images:", len(data))
    return np.array(data)

# Function to train anomaly detection model
def train_anomaly_detector(datasetPath, modelPath):
    print("[INFO] Preparing dataset...")
    data = load_dataset(datasetPath)
    if data is not None and len(data) > 0:
        print("[INFO] Fitting anomaly detection model...")
        model = IsolationForest(n_estimators=100, contamination=0.5, random_state=42)
        model.fit(data)
        print("[INFO] Serializing the model...")
        os.makedirs(os.path.dirname(modelPath), exist_ok=True)
        with open(modelPath, "wb") as f:
            pickle.dump(model, f)
        print("[INFO] Model saved to", modelPath)
    else:
        print("[ERROR] Failed to train the anomaly detection model.")

# Function to test anomaly detection model
def test_anomaly_detector(modelPath, imageFolder, outputDir, normalDir, anomalyDir):
    print("[INFO] Loading anomaly detection model...")
    model = pickle.load(open(modelPath, "rb"))
    os.makedirs(outputDir, exist_ok=True)
    os.makedirs(normalDir, exist_ok=True)
    os.makedirs(anomalyDir, exist_ok=True)
    for filename in os.listdir(imageFolder):
        if filename.endswith(('.jpg', '.jpeg', '.png')):
            imagePath = os.path.join(imageFolder, filename)
            print("[INFO] Loading input image:", imagePath)
            image = cv2.imread(imagePath)
            if image is None:
                print("[WARNING] Failed to read image file:", imagePath)
                continue
            features = extract_common_features(image)
            preds = model.predict([features])[0]
            label = "anomaly" if preds == -1 else "normal"
            color = (0, 0, 255) if preds == -1 else (0, 255, 0)
            cv2.putText(image, label, (10,  25), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
            outputImagePath = os.path.join(outputDir, f"{os.path.splitext(filename)[0]}_{label}.jpg")
            cv2.imwrite(outputImagePath, image)
            print(f"[INFO] Image {filename} classified as {label}. Image saved as {outputImagePath}")

            if label == "normal":
                normalImagePath = os.path.join(normalDir, filename)
                cv2.imwrite(normalImagePath, image)
                print(f"[INFO] Normal image {filename} saved to {normalImagePath}")
            else:
                anomalyImagePath = os.path.join(anomalyDir, filename)
                cv2.imwrite(anomalyImagePath, image)
                print(f"[INFO] Anomaly image {filename} saved to {anomalyImagePath}")

def display_images(image_paths):
    num_images = len(image_paths)
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

    for i, image_path in enumerate(image_paths):
        image = cv2.imread(image_path)
        if image is None:
            print(f"Error: Unable to read image file '{image_path}'. Skipping...")
            continue
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[i].axis('off')

    plt.show()

# Test anomaly detection model
output_dir = "/content/drive/MyDrive/project output/output"
normal_dir = "/content/drive/MyDrive/project output/normal"
anomaly_dir = "/content/drive/MyDrive/project output/anomaly"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(normal_dir):
    os.makedirs(normal_dir)
if not os.path.exists(anomaly_dir):
    os.makedirs(anomaly_dir)

# Train anomaly detection model
train_anomaly_detector("/content/drive/MyDrive/training2", "/path/to/model/anomaly_detector.model")

# Test anomaly detection model
test_anomaly_detector("/path/to/model/anomaly_detector.model", "/content/drive/MyDrive/testdata", output_dir, normal_dir, anomaly_dir)

# Display results
normal_images = [os.path.join(normal_dir, filename) for filename in os.listdir(normal_dir)]
anomaly_images = [os.path.join(anomaly_dir, filename) for filename in os.listdir(anomaly_dir)]

print("Normal Images:")
display_images(normal_images)

print("Anomaly Images:")
display_images(anomaly_images)
# Out:
# [INFO] Preparing dataset...
# [INFO] Loading dataset from /content/drive/MyDrive/training2
# [INFO] Processing image /content/drive/MyDrive/training2/images (6).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/1_43.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (13).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (17).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (23).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (15).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (25).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (9).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/1_57.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/1_46.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/1_55.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/1_62.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/1_60.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/2o.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/3.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/4.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (11).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/9.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (24).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/1_47.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (14).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (12).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (19).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (26).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (22).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/1_44.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (21).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/1_59.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/1_45.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (18).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/2_7.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/2_8.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_131156490_DmgLfo4xdpQgnEeuGm9RD7todmuwUsKY.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (8).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/7.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/8.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/6.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (10).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (16).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/22.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/10.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (7).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/11.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (20).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_afp20030101p101-f1.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/download (2).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (1).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/download (3).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/download (1).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_133356650_OdCl5alz82czIgP1ihhtJg2z1U6Lj07x.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_133356661_Wtkkg92Ju853y3E6ZnPf9uY9xpkFWkXt.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_70042181_GjjOr5CHkQQmgIRHvteZyE0Dbv1LLMlS.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_133356648_8Tv9fYTUMhswAMjcyDVA7aDp8WvN04Hz.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (2).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_133356770_Ra73cUAATgQBXTsrtaWihpuFCDPXSQ1k.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_300px-Ringworm_on_the_arm,_or_tinea_corporis_due_to_Trichophyton_mentagrophytes_PHIL_2938_lores.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/download.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (3).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/images (5).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_208916050_ALPGz6IJnSLNTn7P4tgK1hTWWjxXhGJi.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_211781766_hSMmQM86grmSU0etcko7QXM1T16b2w7Z.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_322548558_CmhjPLZjmbqTTVBf8MKl7ay1jK3zx39z.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/148018-1.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_241-1.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_afp20080515p1415-f2.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_afp20141115p702-f1.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/normal.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/norm2.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_256801673_WXNw73UqDFlx16qVDkNWXu3NXXixaYcx.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/images (4).jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164836.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/15997525228_30a0f1256f_z.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-17 123412.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/26.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000067.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/pexels-photo-6642970.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000068.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164709.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164816.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/240_F_273637270_x4t1i0cHafRl3epUQvKSlYalCmvj7J3u.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164802.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164741.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/afp20080515p1415-f2.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000073.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000072.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000066.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/5.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/25.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/istockphoto-638452360-612x612.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/istockphoto-638446466-612x612.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/istockphoto-638453120-612x612.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164542.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/aug_0_article_2083_cover_en_US.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/pexels-photo-7479635.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/pexels-photo-4046564.jpeg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000276.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000026_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000047_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000050_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000055_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000282.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000040_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000041_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000054_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000027_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000281.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000287.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000078_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000051_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000059_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000064_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000277.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000037_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000053_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000030_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000028_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000063_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000039_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0030070.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0025873.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0026203.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0028188.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0028346.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000048_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0000285.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164651.png
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0029404.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0030015.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0025373.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0025808.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164615.png
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0027188.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0026319.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0027184.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0025411.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0026702.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0029439.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0014636_downsampled.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0026709.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0027563.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/Screenshot 2024-05-15 164542.png
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0027550.jpg
# [INFO] Processing image /content/drive/MyDrive/training2/ISIC_0024386.jpg
# [INFO] Dataset loaded successfully. Total images: 145
# [INFO] Fitting anomaly detection model...
# [INFO] Serializing the model...
# [INFO] Model saved to /path/to/model/anomaly_detector.model
# [INFO] Loading anomaly detection model...
# [INFO] Loading input image: /content/drive/MyDrive/testdata/images (2).jpeg
# [INFO] Image images (2).jpeg classified as normal. Image saved as /content/drive/MyDrive/project output/output/images (2)_normal.jpg
# [INFO] Normal image images (2).jpeg saved to /content/drive/MyDrive/project output/normal/images (2).jpeg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/images (1).jpeg
# [INFO] Image images (1).jpeg classified as normal. Image saved as /content/drive/MyDrive/project output/output/images (1)_normal.jpg
# [INFO] Normal image images (1).jpeg saved to /content/drive/MyDrive/project output/normal/images (1).jpeg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/download.jpeg
# [INFO] Image download.jpeg classified as normal. Image saved as /content/drive/MyDrive/project output/output/download_normal.jpg
# [INFO] Normal image download.jpeg saved to /content/drive/MyDrive/project output/normal/download.jpeg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/images (3).jpeg
# [INFO] Image images (3).jpeg classified as normal. Image saved as /content/drive/MyDrive/project output/output/images (3)_normal.jpg
# [INFO] Normal image images (3).jpeg saved to /content/drive/MyDrive/project output/normal/images (3).jpeg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0.jpg
# [INFO] Image 240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0_normal.jpg
# [INFO] Normal image 240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0.jpg saved to /content/drive/MyDrive/project output/normal/240_F_221429397_wXSkhqRkUEQuhBMel67qxSfxuz03Eos0.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/26.jpg
# [INFO] Image 26.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/26_normal.jpg
# [INFO] Normal image 26.jpg saved to /content/drive/MyDrive/project output/normal/26.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/Screenshot 2024-05-15 164836.jpg
# [INFO] Image Screenshot 2024-05-15 164836.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/Screenshot 2024-05-15 164836_normal.jpg
# [INFO] Normal image Screenshot 2024-05-15 164836.jpg saved to /content/drive/MyDrive/project output/normal/Screenshot 2024-05-15 164836.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/Screenshot 2024-05-15 164816.jpg
# [INFO] Image Screenshot 2024-05-15 164816.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/Screenshot 2024-05-15 164816_normal.jpg
# [INFO] Normal image Screenshot 2024-05-15 164816.jpg saved to /content/drive/MyDrive/project output/normal/Screenshot 2024-05-15 164816.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/Screenshot 2024-05-15 164709.jpg
# [INFO] Image Screenshot 2024-05-15 164709.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/Screenshot 2024-05-15 164709_normal.jpg
# [INFO] Normal image Screenshot 2024-05-15 164709.jpg saved to /content/drive/MyDrive/project output/normal/Screenshot 2024-05-15 164709.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/Screenshot 2024-05-15 164802.jpg
# [INFO] Image Screenshot 2024-05-15 164802.jpg classified as normal. Image saved as /content/drive/MyDrive/project output/output/Screenshot 2024-05-15 164802_normal.jpg
# [INFO] Normal image Screenshot 2024-05-15 164802.jpg saved to /content/drive/MyDrive/project output/normal/Screenshot 2024-05-15 164802.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0000075.jpg
# [INFO] Image ISIC_0000075.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0000075_anomaly.jpg
# [INFO] Anomaly image ISIC_0000075.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0000075.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/aug_0_jock-itch-1024x683.jpeg
# [INFO] Image aug_0_jock-itch-1024x683.jpeg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/aug_0_jock-itch-1024x683_anomaly.jpg
# [INFO] Anomaly image aug_0_jock-itch-1024x683.jpeg saved to /content/drive/MyDrive/project output/anomaly/aug_0_jock-itch-1024x683.jpeg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0000065_downsampled.jpg
# [INFO] Image ISIC_0000065_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0000065_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0000065_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0000065_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0000097_downsampled.jpg
# [INFO] Image ISIC_0000097_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0000097_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0000097_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0000097_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0011112.jpg
# [INFO] Image ISIC_0011112.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0011112_anomaly.jpg
# [INFO] Anomaly image ISIC_0011112.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0011112.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0011135.jpg
# [INFO] Image ISIC_0011135.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0011135_anomaly.jpg
# [INFO] Anomaly image ISIC_0011135.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0011135.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0000044_downsampled.jpg
# [INFO] Image ISIC_0000044_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0000044_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0000044_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0000044_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0000101_downsampled.jpg
# [INFO] Image ISIC_0000101_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0000101_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0000101_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0000101_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0014609_downsampled.jpg
# [INFO] Image ISIC_0014609_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0014609_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0014609_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0014609_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0014605_downsampled.jpg
# [INFO] Image ISIC_0014605_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0014605_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0014605_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0014605_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0026206.jpg
# [INFO] Image ISIC_0026206.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0026206_anomaly.jpg
# [INFO] Anomaly image ISIC_0026206.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0026206.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0024747.jpg
# [INFO] Image ISIC_0024747.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0024747_anomaly.jpg
# [INFO] Anomaly image ISIC_0024747.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0024747.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0015038_downsampled.jpg
# [INFO] Image ISIC_0015038_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0015038_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0015038_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0015038_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0015170_downsampled.jpg
# [INFO] Image ISIC_0015170_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0015170_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0015170_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0015170_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0029760.jpg
# [INFO] Image ISIC_0029760.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0029760_anomaly.jpg
# [INFO] Anomaly image ISIC_0029760.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0029760.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/Screenshot 2024-05-15 164615.png
# [INFO] Image Screenshot 2024-05-15 164615.png classified as normal. Image saved as /content/drive/MyDrive/project output/output/Screenshot 2024-05-15 164615_normal.jpg
# [INFO] Normal image Screenshot 2024-05-15 164615.png saved to /content/drive/MyDrive/project output/normal/Screenshot 2024-05-15 164615.png
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0015233_downsampled.jpg
# [INFO] Image ISIC_0015233_downsampled.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0015233_downsampled_anomaly.jpg
# [INFO] Anomaly image ISIC_0015233_downsampled.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0015233_downsampled.jpg
# [INFO] Loading input image: /content/drive/MyDrive/testdata/ISIC_0029578.jpg
# [INFO] Image ISIC_0029578.jpg classified as anomaly. Image saved as /content/drive/MyDrive/project output/output/ISIC_0029578_anomaly.jpg
# [INFO] Anomaly image ISIC_0029578.jpg saved to /content/drive/MyDrive/project output/anomaly/ISIC_0029578.jpg
# Normal Images:
# Error: Unable to read image file '/content/drive/MyDrive/project output/normal/.ipynb_checkpoints'. Skipping...
# Anomaly Images:

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Function to evaluate anomaly detection performance
def evaluate_anomaly_detection(normal_images, anomaly_images):
    # True labels
    true_labels = [0] * len(normal_images) + [1] * len(anomaly_images)

    # Predicted labels
    predicted_labels = [0] * len(normal_images) + [1] * len(anomaly_images)

    # Calculate precision, recall, and F1-score
    precision = precision_score(true_labels, predicted_labels)
    recall = recall_score(true_labels, predicted_labels)
    f1 = f1_score(true_labels, predicted_labels)

    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1)

# Evaluate anomaly detection performance
evaluate_anomaly_detection(normal_images, anomaly_images)
# Out:
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0

# %%
import os
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.layers import Dense
from keras.models import Sequential
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from keras.layers import Convolution2D,Dense,MaxPool2D,Activation,Dropout,Flatten
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D

# %%
def get_files(directory):
  if not os.path.exists(directory):
    return 0
  count=0
  # crawls inside folders
  for current_path,dirs,files in os.walk(directory):
    for dr in dirs:
      count+= len(glob.glob(os.path.join(current_path,dr+"/*")))
  return count
train_dir ="/content/drive/MyDrive/skin"
test_dir="/content/drive/MyDrive/project output/anomaly"

# %%
 #train file image count
train_samples =get_files(train_dir)
#to get tags
num_classes=len(glob.glob(train_dir+"/*"))
#test file image count
test_samples=get_files(test_dir)
print(num_classes,"Classes")
print(train_samples,"Train images")
print(test_samples,"Test images")

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
    )
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
validation_generator = test_datagen.flow_from_directory(
                       test_dir,
                       target_size=(229, 229),
                       batch_size=4,
                       class_mode='categorical')

# %%
input_shape=(229,229,3)
train_generator =train_datagen.flow_from_directory(train_dir,target_size=(224,224),batch_size=4)
test_generator=test_datagen.flow_from_directory(test_dir,shuffle=True,target_size=(224,224),batch_size=4)

# %%
# Define the parameter grid for hyperparameter tuning
param_grid = {
    'learning_rate': [0.001, 0.001],
    'batch_size': [32, 64]
}

# %%
def create_Base_model_from_Inceptionv3():
    model_inceptionv3 = InceptionV3(
        weights = "imagenet",# control point from which model is started
        include_top=False, # to include/exclude the first 3 layers
        input_shape = (229,229, 3)) # image size
    # don't train existing weights
    for layer in model_inceptionv3.layers:
      layer.trainable = False
    return model_inceptionv3
create_Base_model_from_Inceptionv3().summary()

# %%
from tensorflow.keras.metrics import Precision, Recall

# %%
def add_custom_layers_inceptionv3():
    #Adding custom Layers
    model_inceptionv3 = create_Base_model_from_Inceptionv3()
    x = model_inceptionv3.output
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(256, activation="relu")(x)
    predictions = tf.keras.layers.Dense(6, activation="softmax")(x)
    # creating the final model
    final_model = tf.keras.models.Model(
        inputs = model_inceptionv3.input,
        outputs = predictions)

    final_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy',Precision(), Recall()])
    return final_model

add_custom_layers_inceptionv3().summary()

# %%
class SkinModel(tf.keras.Model):
    def create_Inceptionv3(self, learning_rate=0.001, optimizer='adam'):
        super(SkinModel, self).__init__()
        base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(229, 229, 3))
        for layer in base_model.layers:
            layer.trainable = False

        x = Flatten()(base_model.output)
        x = Dense(256, activation='relu')(x)
        predictions = Dense(num_classes, activation='softmax')(x)

        self.model = Model(inputs=base_model.input, outputs=predictions)
        self.model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy',metrics=['accuracy',Precision(), Recall()])

        # Add a score method to the model
        def score(self, X, y):
            y_pred = self.predict(X)
            y_true = np.argmax(y, axis=1)
            y_pred_classes = np.argmax(y_pred, axis=1)
            return accuracy_score(y_true, y_pred_classes)

        self.model.score = score

    def fit(self, X, y, epochs=5, batch_size=32):
        self.model.fit(X, y, epochs=epochs, batch_size=batch_size)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the grid search object
grid_search = GridSearchCV(
    estimator=SkinModel(),
    param_grid=param_grid,
    cv=3,
    verbose=2
)

# %%
# Fit the grid search to the data
grid_result = grid_search

# %%
model_from_inceptionv3 = add_custom_layers_inceptionv3()
history3 = model_from_inceptionv3.fit(train_generator,
                      steps_per_epoch=None,
                      epochs=5,
                      validation_data=validation_generator,
                      validation_steps=None,
                      verbose=1,
                      callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.3,patience=3, min_lr=0.001)],
                      use_multiprocessing=False,
                      shuffle=True)
# Out:
# Epoch 1/5
# 121/121 [==============================] - ETA: 0s - loss: 9.4565 - accuracy: 0.5946 - precision_3: 0.5987 - recall_3: 0.5925
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision_3,recall_3,lr
# 121/121 [==============================] - 222s 2s/step - loss: 9.4565 - accuracy: 0.5946 - precision_3: 0.5987 - recall_3: 0.5925 - lr: 0.0010
# Epoch 2/5
# 121/121 [==============================] - ETA: 0s - loss: 2.4579 - accuracy: 0.7630 - precision_3: 0.7625 - recall_3: 0.7609
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision_3,recall_3,lr
# 121/121 [==============================] - 86s 711ms/step - loss: 2.4579 - accuracy: 0.7630 - precision_3: 0.7625 - recall_3: 0.7609 - lr: 0.0010
# Epoch 3/5
# 121/121 [==============================] - ETA: 0s - loss: 1.0056 - accuracy: 0.8046 - precision_3: 0.8079 - recall_3: 0.8046
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision_3,recall_3,lr
# 121/121 [==============================] - 89s 735ms/step - loss: 1.0056 - accuracy: 0.8046 - precision_3: 0.8079 - recall_3: 0.8046 - lr: 0.0010
# Epoch 4/5
# 121/121 [==============================] - ETA: 0s - loss: 0.5501 - accuracy: 0.8482 - precision_3: 0.8565 - recall_3: 0.8441
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision_3,recall_3,lr
# 121/121 [==============================] - 88s 724ms/step - loss: 0.5501 - accuracy: 0.8482 - precision_3: 0.8565 - recall_3: 0.8441 - lr: 0.0010
# Epoch 5/5
# 121/121 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.8649 - precision_3: 0.8653 - recall_3: 0.8545
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,precision_3,recall_3,lr
# 121/121 [==============================] - 88s 726ms/step - loss: 0.5355 - accuracy: 0.8649 - precision_3: 0.8653 - recall_3: 0.8545 - lr: 0.0010

# %%
model_from_inceptionv3.save('/content/drive/MyDrive/Colab Notebooks/Model/skinincep.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
model_inceptionv3=load_model('/content/drive/MyDrive/Colab Notebooks/Model/skinincep.h5')

# %%
# !pip install tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.10/dist-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (1.25.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (3.20.3)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-hub) (2.15.1)
# Requirement already satisfied: tensorflow<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (24.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.64.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15->tf-keras>=2.14.1->tensorflow-hub) (3.2.2)

# %%
from glob import glob
from sklearn.metrics import precision_score, recall_score


def predict_disease(model_inceptionv3, img_folder):
    """Predicts disease class for all images in a folder and calculates precision and recall.

    Args:
        model_inceptionv3: Trained Keras model for disease prediction.
        img_folder: Path to the folder containing images.

    Returns:
        A dictionary containing precision, recall, and predicted class probabilities for each image.
    """

    img_size = (229, 229)
    class_names = list(train_generator.class_indices.keys())

    # Get all image paths in the folder
    image_paths = glob(os.path.join(img_folder, "*.jpg"))  # Modify for other extensions if needed

    all_predictions = {}  # Dictionary to store predictions for all images
    true_labels = []      # List to store true labels if available for evaluation

    for img_path in image_paths:
        img = tf.keras.utils.load_img(img_path, target_size=img_size, color_mode='rgb')
        array = tf.keras.utils.img_to_array(img)
        array = array / 255.0
        img_array = np.expand_dims(array, axis=0)
        preds = model_inceptionv3.predict(img_array)

        formatted_predictions = [f'{value:.2f}' for value in preds[0]]  # Assuming single prediction per image

        top_prob_index = np.argmax(formatted_predictions)
        top_prob = round(float(formatted_predictions[top_prob_index].replace(",", ".")) * 100, 2)

        print(f"Image: {img_path}")
        print("Probability for each class:", sorted(zip(class_names, formatted_predictions), key=lambda x: x[1], reverse=True))
        print(f"Predicted Class: {list(class_names)[top_prob_index]}; Prob: {top_prob}%")
        print("-" * 50)  # Optional separator between images

        all_predictions[img_path] = {
            "predicted_class": list(class_names)[top_prob_index],
            "probability": top_prob,
            "class_probabilities": formatted_predictions,
        }

        # Add true label logic here if you have ground truth data
        # true_labels.append(your_true_label_function(img_path))

    # Calculate precision and recall if true labels are available
    if true_labels:
        y_true = [class_names.index(label) for label in true_labels]  # Convert true labels to indices
        y_pred = [all_predictions[path]["predicted_class"] for path in image_paths]

        for class_name in class_names:
            class_index = class_names.index(class_name)
            precision = precision_score(y_true, y_pred, pos_label=class_index, average='binary')
            recall = recall_score(y_true, y_pred, pos_label=class_index, average='binary')
            print(f"Precision for class '{class_name}': {precision:.4f}")
            print(f"Recall for class '{class_name}': {recall:.4f}")

    return all_predictions

# Example usage with potential ground truth label logic (replace with your implementation)
all_predictions = predict_disease(model_inceptionv3, "/content/drive/MyDrive/project output/anomaly")
print(all_predictions)
# Out:
# 1/1 [==============================] - 0s 196ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0000075.jpg
# Probability for each class: [('Melanocytic nevus', '0.72'), ('Benign keratosis', '0.28'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Melanocytic nevus; Prob: 72.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 216ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0000065_downsampled.jpg
# Probability for each class: [('Benign keratosis', '0.89'), ('Melanocytic nevus', '0.11'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Benign keratosis; Prob: 89.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 204ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0000097_downsampled.jpg
# Probability for each class: [('Benign keratosis', '0.97'), ('Melanocytic nevus', '0.03'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Benign keratosis; Prob: 97.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 266ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0011112.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 337ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0011135.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 342ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0000044_downsampled.jpg
# Probability for each class: [('Benign keratosis', '0.66'), ('Melanocytic nevus', '0.34'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Benign keratosis; Prob: 66.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 328ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0000101_downsampled.jpg
# Probability for each class: [('Melanocytic nevus', '0.96'), ('Benign keratosis', '0.03'), ('Actinic keratosis', '0.01'), ('.ipynb_checkpoints', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Melanocytic nevus; Prob: 96.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 361ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0014609_downsampled.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 307ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0014605_downsampled.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 317ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0026206.jpg
# Probability for each class: [('Melanocytic nevus', '0.62'), ('Benign keratosis', '0.38'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Melanocytic nevus; Prob: 62.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 304ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0015038_downsampled.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 360ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0024747.jpg
# Probability for each class: [('Melanocytic nevus', '0.53'), ('Dermatofibroma', '0.47'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Benign keratosis', '0.00')]
# Predicted Class: Melanocytic nevus; Prob: 53.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 364ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0015170_downsampled.jpg
# Probability for each class: [('Benign keratosis', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 225ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0029760.jpg
# Probability for each class: [('Dermatofibroma', '1.00'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Benign keratosis', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Dermatofibroma; Prob: 100.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 219ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0015233_downsampled.jpg
# Probability for each class: [('Benign keratosis', '0.99'), ('Melanocytic nevus', '0.01'), ('.ipynb_checkpoints', '0.00'), ('Actinic keratosis', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00')]
# Predicted Class: Benign keratosis; Prob: 99.0%
# --------------------------------------------------
# 1/1 [==============================] - 0s 225ms/step
# Image: /content/drive/MyDrive/project output/anomaly/ISIC_0029578.jpg
# Probability for each class: [('Benign keratosis', '0.99'), ('Actinic keratosis', '0.01'), ('.ipynb_checkpoints', '0.00'), ('Atopic Dermatitis', '0.00'), ('Dermatofibroma', '0.00'), ('Melanocytic nevus', '0.00')]
# Predicted Class: Benign keratosis; Prob: 99.0%
# --------------------------------------------------
# {'/content/drive/MyDrive/project output/anomaly/ISIC_0000075.jpg': {'predicted_class': 'Melanocytic nevus', 'probability': 72.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.28', '0.00', '0.72']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0000065_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 89.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.89', '0.00', '0.11']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0000097_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 97.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.97', '0.00', '0.03']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0011112.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0011135.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0000044_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 66.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.66', '0.00', '0.34']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0000101_downsampled.jpg': {'predicted_class': 'Melanocytic nevus', 'probability': 96.0, 'class_probabilities': ['0.00', '0.01', '0.00', '0.03', '0.00', '0.96']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0014609_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0014605_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0026206.jpg': {'predicted_class': 'Melanocytic nevus', 'probability': 62.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.38', '0.00', '0.62']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0015038_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0024747.jpg': {'predicted_class': 'Melanocytic nevus', 'probability': 53.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.00', '0.47', '0.53']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0015170_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '1.00', '0.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0029760.jpg': {'predicted_class': 'Dermatofibroma', 'probability': 100.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.00', '1.00', '0.00']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0015233_downsampled.jpg': {'predicted_class': 'Benign keratosis', 'probability': 99.0, 'class_probabilities': ['0.00', '0.00', '0.00', '0.99', '0.00', '0.01']}, '/content/drive/MyDrive/project output/anomaly/ISIC_0029578.jpg': {'predicted_class': 'Benign keratosis', 'probability': 99.0, 'class_probabilities': ['0.00', '0.01', '0.00', '0.99', '0.00', '0.00']}}
